# %%
import pandas as pd

# Define the path to your Excel file
excel_file = 'C:\\Users\\blues\\Desktop\\Project 2.xlsx'

# Read the Excel file
df = pd.read_excel(excel_file)

# Display the DataFrame
df
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0    2020-08-07 12:02:00             Female  18.0          Engineering
# 1    2020-08-07 12:04:00               Male  21.0    Islamic education
# 2    2020-08-07 12:05:00               Male  19.0                  BIT
# 3    2020-08-07 12:06:00             Female  22.0                 Laws
# 4    2020-08-07 12:13:00               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
import pandas as pd

# Read the Excel file into a DataFrame
df = pd.read_excel('C:\\Users\\blues\\Desktop\\Project 2.xlsx')

# Specify the columns to delete
columns_to_delete = ['Timestamp']
    
# Check if the columns exist in the DataFrame
existing_columns = df.columns.tolist()
columns_to_drop = [col for col in columns_to_delete if col in existing_columns]

# Delete the specified columns
df = df.drop(columns=columns_to_drop)

# Display the modified DataFrame
df
# Create a new target column based on existing columns or data manipulation
df['Target'] = df['Do you have depression'] 
df['Target#'] = df['Do you have depression#'] 
# Display the DataFrame with the new target column
df
# Out:
#     Choose your gender   Age What is your course? Your current year of Study  \
# 0               Female  18.0          Engineering                     year 1
# 1                 Male  21.0    Islamic education                     year 2
# 2                 Male  19.0                  BIT                     Year 1
# 3               Female  22.0                 Laws                     year 3
# 4                 Male  23.0         Mathemathics                     year 4
# ..                 ...   ...                  ...                        ...
# 96              Female  21.0                  BCS                     year 1
# 97                Male  18.0          Engineering                     Year 2
# 98              Female  19.0             Nursing                      Year 3
# 99              Female  23.0     Pendidikan Islam                     year 4
# 100               Male  20.0   Biomedical science                     Year 2
#
# ...
